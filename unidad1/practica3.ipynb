# %% [markdown]
# <a href="https://colab.research.google.com/github/Edgar-Tinoco/probabilidad/blob/main/unidad1/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadística**
# ## **Unidad 1**
# ### **Practica 3. Tabla de frecuencias y regla de Sturges..**
# ### Docente: *Dr. José Gabriel Rodríguez Rivas*
# ### Alumno: Edgar Giovanni tinoco nava

# %%
import random
edades = []
for i in range(100):
    numero_aleatorio = random.randint( 18, 70)
    edades.append (numero_aleatorio)
print(edades)
# Out:
# [44, 35, 50, 43, 28, 37, 27, 62, 32, 43, 18, 51, 33, 48, 64, 59, 43, 44, 27, 34, 26, 39, 67, 36, 35, 63, 37, 45, 29, 52, 57, 31, 27, 65, 51, 40, 55, 34, 37, 62, 58, 64, 32, 53, 66, 25, 25, 33, 46, 53, 39, 52, 31, 19, 58, 34, 57, 18, 31, 36, 39, 46, 29, 55, 58, 33, 53, 25, 56, 49, 22, 47, 65, 45, 23, 57, 23, 54, 61, 57, 50, 26, 52, 34, 69, 47, 34, 20, 52, 35, 39, 21, 62, 70, 42, 58, 64, 45, 66, 30]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame (edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    30
# 1    70
# 2    26
# 3    43
# 4    38

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 33    20           1
# 30    21           2
# 32    22           1
# 12    23           3
# 26    24           2
# 28    25           2
# 1     26           4
# 25    27           2
# 11    28           3
# 42    29           1
# 2     30           4
# 6     32           3
# 27    33           2
# 8     34           3
# 36    35           1
# 39    36           1
# 9     38           3
# 17    39           3
# 38    40           1
# 7     41           3
# 19    42           3
# 5     43           3
# 23    44           2
# 40    46           1
# 3     47           4
# 24    48           2
# 37    49           1
# 20    52           2
# 35    53           1
# 41    54           1
# 0     55           5
# 13    56           3
# 29    58           2
# 34    59           1
# 14    60           3
# 18    61           3
# 10    63           3
# 22    64           2
# 16    65           3
# 15    66           3
# 31    67           1
# 21    68           2
# 4     69           4

# %%
tabla_frecuencias['frec relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  frec relativa
# 33    20           1           0.01
# 30    21           2           0.02
# 32    22           1           0.01
# 12    23           3           0.03
# 26    24           2           0.02
# 28    25           2           0.02
# 1     26           4           0.04
# 25    27           2           0.02
# 11    28           3           0.03
# 42    29           1           0.01
# 2     30           4           0.04
# 6     32           3           0.03
# 27    33           2           0.02
# 8     34           3           0.03
# 36    35           1           0.01
# 39    36           1           0.01
# 9     38           3           0.03
# 17    39           3           0.03
# 38    40           1           0.01
# 7     41           3           0.03
# 19    42           3           0.03
# 5     43           3           0.03
# 23    44           2           0.02
# 40    46           1           0.01
# 3     47           4           0.04
# 24    48           2           0.02
# 37    49           1           0.01
# 20    52           2           0.02
# 35    53           1           0.01
# 41    54           1           0.01
# 0     55           5           0.05
# 13    56           3           0.03
# 29    58           2           0.02
# 34    59           1           0.01
# 14    60           3           0.03
# 18    61           3           0.03
# 10    63           3           0.03
# 22    64           2           0.02
# 16    65           3           0.03
# 15    66           3           0.03
# 31    67           1           0.01
# 21    68           2           0.02
# 4     69           4           0.04

# %%
tabla_frecuencias['frec relativa'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  frec relativa
# 33    20           1            1.0
# 30    21           2            2.0
# 32    22           1            1.0
# 12    23           3            3.0
# 26    24           2            2.0
# 28    25           2            2.0
# 1     26           4            4.0
# 25    27           2            2.0
# 11    28           3            3.0
# 42    29           1            1.0
# 2     30           4            4.0
# 6     32           3            3.0
# 27    33           2            2.0
# 8     34           3            3.0
# 36    35           1            1.0
# 39    36           1            1.0
# 9     38           3            3.0
# 17    39           3            3.0
# 38    40           1            1.0
# 7     41           3            3.0
# 19    42           3            3.0
# 5     43           3            3.0
# 23    44           2            2.0
# 40    46           1            1.0
# 3     47           4            4.0
# 24    48           2            2.0
# 37    49           1            1.0
# 20    52           2            2.0
# 35    53           1            1.0
# 41    54           1            1.0
# 0     55           5            5.0
# 13    56           3            3.0
# 29    58           2            2.0
# 34    59           1            1.0
# 14    60           3            3.0
# 18    61           3            3.0
# 10    63           3            3.0
# 22    64           2            2.0
# 16    65           3            3.0
# 15    66           3            3.0
# 31    67           1            1.0
# 21    68           2            2.0
# 4     69           4            4.0

# %%
tabla_frecuencias['frec relativa'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  frec relativa
# 33    20           1              1
# 30    21           2              3
# 32    22           1              4
# 12    23           3              7
# 26    24           2              9
# 28    25           2             11
# 1     26           4             15
# 25    27           2             17
# 11    28           3             20
# 42    29           1             21
# 2     30           4             25
# 6     32           3             28
# 27    33           2             30
# 8     34           3             33
# 36    35           1             34
# 39    36           1             35
# 9     38           3             38
# 17    39           3             41
# 38    40           1             42
# 7     41           3             45
# 19    42           3             48
# 5     43           3             51
# 23    44           2             53
# 40    46           1             54
# 3     47           4             58
# 24    48           2             60
# 37    49           1             61
# 20    52           2             63
# 35    53           1             64
# 41    54           1             65
# 0     55           5             70
# 13    56           3             73
# 29    58           2             75
# 34    59           1             76
# 14    60           3             79
# 18    61           3             82
# 10    63           3             85
# 22    64           2             87
# 16    65           3             90
# 15    66           3             93
# 31    67           1             94
# 21    68           2             96
# 4     69           4            100

# %% [markdown]
# # reglas de sturges

# %%
import math

# %%
print(edades)
# Out:
# [44, 35, 50, 43, 28, 37, 27, 62, 32, 43, 18, 51, 33, 48, 64, 59, 43, 44, 27, 34, 26, 39, 67, 36, 35, 63, 37, 45, 29, 52, 57, 31, 27, 65, 51, 40, 55, 34, 37, 62, 58, 64, 32, 53, 66, 25, 25, 33, 46, 53, 39, 52, 31, 19, 58, 34, 57, 18, 31, 36, 39, 46, 29, 55, 58, 33, 53, 25, 56, 49, 22, 47, 65, 45, 23, 57, 23, 54, 61, 57, 50, 26, 52, 34, 69, 47, 34, 20, 52, 35, 39, 21, 62, 70, 42, 58, 64, 45, 66, 30]

# %%
df = pd.DataFrame({'edad' : edades})
df
# Out:
#     edad
# 0     44
# 1     35
# 2     50
# 3     43
# 4     28
# ..   ...
# 95    58
# 96    64
# 97    45
# 98    66
# 99    30
#
# [100 rows x 1 columns]

# %%
n = len (edades)
K = int( 1 + math.log2(n))
print("Valor de n = ", n, " \nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['clase', 'frecuencia']
tabla_frecuencias
# Out:
#     Edad  Frecuencia  frec relativa
# 33    20           1              1
# 30    21           2              3
# 32    22           1              4
# 12    23           3              7
# 26    24           2              9
# 28    25           2             11
# 1     26           4             15
# 25    27           2             17
# 11    28           3             20
# 42    29           1             21
# 2     30           4             25
# 6     32           3             28
# 27    33           2             30
# 8     34           3             33
# 36    35           1             34
# 39    36           1             35
# 9     38           3             38
# 17    39           3             41
# 38    40           1             42
# 7     41           3             45
# 19    42           3             48
# 5     43           3             51
# 23    44           2             53
# 40    46           1             54
# 3     47           4             58
# 24    48           2             60
# 37    49           1             61
# 20    52           2             63
# 35    53           1             64
# 41    54           1             65
# 0     55           5             70
# 13    56           3             73
# 29    58           2             75
# 34    59           1             76
# 14    60           3             79
# 18    61           3             82
# 10    63           3             85
# 22    64           2             87
# 16    65           3             90
# 15    66           3             93
# 31    67           1             94
# 21    68           2             96
# 4     69           4            100

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='clase')
tabla_frecuencia
# Out:
#               clase  frecuencia
# 5  (17.947, 25.429]          11
# 2  (25.429, 32.857]          14
# 0  (32.857, 40.286]          21
# 4  (40.286, 47.714]          13
# 1  (47.714, 55.143]          16
# 3  (55.143, 62.571]          14
# 6    (62.571, 70.0]          11

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] /n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               clase  frecuencia  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 5  (17.947, 25.429]          11      0.11       11.0       11         0.11
# 2  (25.429, 32.857]          14      0.14       14.0       25         0.25
# 0  (32.857, 40.286]          21      0.21       21.0       46         0.46
# 4  (40.286, 47.714]          13      0.13       13.0       59         0.59
# 1  (47.714, 55.143]          16      0.16       16.0       75         0.75
# 3  (55.143, 62.571]          14      0.14       14.0       89         0.89
# 6    (62.571, 70.0]          11      0.11       11.0      100         1.00
#
#    Frec Porc Ac
# 5          11.0
# 2          25.0
# 0          46.0
# 4          59.0
# 1          75.0
# 3          89.0
# 6         100.0

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
import matplotlib.pyplot as plt
plt.hist(df['edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
